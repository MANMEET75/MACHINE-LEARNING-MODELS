# %% [markdown]
# ## Importing the essential libraries over here

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing the dataset over here

# %%
data=pd.read_csv("dogs-ranking-dataset.csv")

# %%
data.head()
# Out:
#                     Breed      type  score  popularity ranking  size  \
# 0          Border Terrier   terrier   3.61                  61     1
# 1           Cairn Terrier   terrier   3.53                  48     1
# 2          Siberian Husky   working   3.22                  16     2
# 3  Welsh Springer Spaniel  sporting   3.34                  81     2
# 4  English Cocker Spaniel  sporting   3.33                  51     2
#
#     intelligence           congential ailments  score for kids  size.1  \
# 0  Above average                          none            4.99   small
# 1  Above average  'lion jaw', heart problems              4.91   small
# 2        Average                          none            4.72  medium
# 3  Above average                  hip problems            4.71  medium
# 4      Excellent                          none            4.70  medium
#
#   $LIFETIME COST  INTELLIGENCE RANK INTELLIGENCE %  LONGEVITY(YEARS)  \
# 0       $22,638                  30            70%             14.00
# 1       $21,992                  35            61%             13.84
# 2       $22,049                  45            45%             12.58
# 3       $20,224                  31            69%             12.49
# 4       $18,993                  18            82%             11.66
#
#    NUMBER OF GENETIC AILMENTS              GENETIC AILMENTS PURCHASE PRICE  \
# 0                           0                          none          $833
# 1                           2  'lion jaw', heart problems            $435
# 2                           0                          none          $650
# 3                           1                  hip problems          $750
# 4                           0                          none          $800
#
#   FOOD COSTS PER YEAR    GROOMING FREQUNCY  SUITABILITY FOR CHILDREN
# 0               $324           Once a week                         1
# 1               $324           Once a week                         1
# 2               $466   Once in a few weeks                         1
# 3               $324           Once a week                         1
# 4               $324           Once a week                         1

# %%
data['LONGEVITY(YEARS)'].min()
# Out:
# 6.29

# %%
data['LONGEVITY(YEARS)'].max()
# Out:
# 16.5

# %% [markdown]
# ## Taking care of duplicate observations if present over here

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Taking care of missing values if present over here

# %%
data.isnull().sum()
# Out:
# Breed                         0
# type                          0
# score                         0
# popularity ranking            0
# size                          0
# intelligence                  0
# congential ailments           0
# score for kids                0
# size.1                        0
# $LIFETIME COST                0
# INTELLIGENCE RANK             0
# INTELLIGENCE %                0
# LONGEVITY(YEARS)              0
# NUMBER OF GENETIC AILMENTS    0
# GENETIC AILMENTS              0
# PURCHASE PRICE                0
# FOOD COSTS PER YEAR           0
# GROOMING FREQUNCY             0
# SUITABILITY FOR CHILDREN      0
# dtype: int64

# %% [markdown]
# ## Performing Little Bit of Data Cleaning over here

# %%
data['$LIFETIME COST']=data['$LIFETIME COST'].str.replace("$","")
data['$LIFETIME COST']=data['$LIFETIME COST'].str.replace(",","")

data['PURCHASE PRICE']=data['PURCHASE PRICE'].str.replace("$","")
data['PURCHASE PRICE']=data['PURCHASE PRICE'].str.replace(",","")

data['FOOD COSTS PER YEAR']=data['FOOD COSTS PER YEAR'].str.replace("$","")
data['FOOD COSTS PER YEAR']=data['FOOD COSTS PER YEAR'].str.replace(",","")

data['INTELLIGENCE %']=data['INTELLIGENCE %'].str.replace("%","")

# %%
data.head(1)
# Out:
#             Breed     type  score  popularity ranking  size   intelligence  \
# 0  Border Terrier  terrier   3.61                  61     1  Above average
#
#   congential ailments  score for kids size.1 $LIFETIME COST  \
# 0                none            4.99  small         22638
#
#    INTELLIGENCE RANK INTELLIGENCE %  LONGEVITY(YEARS)  \
# 0                 30             70              14.0
#
#    NUMBER OF GENETIC AILMENTS GENETIC AILMENTS PURCHASE PRICE  \
# 0                           0             none           833
#
#   FOOD COSTS PER YEAR GROOMING FREQUNCY  SUITABILITY FOR CHILDREN
# 0                324        Once a week                         1

# %% [markdown]
# ## Filtering all the numerical features over here

# %%
numerical_features=[feature for feature in data.columns if data[feature].dtype!='O']
for feature in numerical_features:
  print(feature)
# Out:
# score
# popularity ranking
# size
# score for kids
# INTELLIGENCE RANK
# LONGEVITY(YEARS)
# NUMBER OF GENETIC AILMENTS
# SUITABILITY FOR CHILDREN

# %%
data[numerical_features]
# Out:
#     score  popularity ranking  size  score for kids  INTELLIGENCE RANK  \
# 0    3.61                  61     1            4.99                 30
# 1    3.53                  48     1            4.91                 35
# 2    3.22                  16     2            4.72                 45
# 3    3.34                  81     2            4.71                 31
# 4    3.33                  51     2            4.70                 18
# ..    ...                 ...   ...             ...                ...
# 82   1.82                  47     3            2.57                 50
# 83   1.66                  42     3            2.54                 75
# 84   1.76                  54     2            2.51                 77
# 85   1.95                  41     3            2.33                 54
# 86   0.99                   6     2            1.86                 78
#
#     LONGEVITY(YEARS)  NUMBER OF GENETIC AILMENTS  SUITABILITY FOR CHILDREN
# 0              14.00                           0                         1
# 1              13.84                           2                         1
# 2              12.58                           0                         1
# 3              12.49                           1                         1
# 4              11.66                           0                         1
# ..               ...                         ...                       ...
# 82             10.67                           2                         2
# 83              6.75                           2                         2
# 84              9.01                           2                         2
# 85             10.16                           1                         3
# 86              6.29                           5                         2
#
# [87 rows x 8 columns]

# %% [markdown]
# ## Filtering all the categorical features over here

# %%
cat_features=[feature for feature in data.columns if data[feature].dtype=="O"]
for feature in cat_features:
  print(feature)
# Out:
# Breed
# type
# intelligence
# congential ailments
# size.1
# $LIFETIME COST
# INTELLIGENCE %
# GENETIC AILMENTS
# PURCHASE PRICE
# FOOD COSTS PER YEAR
# GROOMING FREQUNCY

# %%
data[cat_features]
# Out:
#                      Breed          type   intelligence  \
# 0           Border Terrier       terrier  Above average
# 1            Cairn Terrier       terrier  Above average
# 2           Siberian Husky       working        Average
# 3   Welsh Springer Spaniel      sporting  Above average
# 4   English Cocker Spaniel      sporting      Excellent
# ..                     ...           ...            ...
# 82        Alaskan Malamute       working        Average
# 83              Bloodhound         hound         Lowest
# 84               Chow Chow  non-sporting         Lowest
# 85                   Akita       working        Average
# 86                 Bulldog  non-sporting         Lowest
#
#                           congential ailments  size.1 $LIFETIME COST  \
# 0                                        none   small         22638
# 1                'lion jaw', heart problems     small         21992
# 2                                        none  medium         22049
# 3                                hip problems  medium         20224
# 4                                        none  medium         18993
# ..                                        ...     ...            ...
# 82                     hip problems, dwarfism   large         21986
# 83         fatal stomach bloat, skin problems   large         13824
# 84                          eye, hip problems  medium         15898
# 85                               hip problems   large         20994
# 86  breathing, hip, heart problems, 'dry eye'  medium         13479
#
#    INTELLIGENCE %                           GENETIC AILMENTS PURCHASE PRICE  \
# 0              70                                       none           833
# 1              61               'lion jaw', heart problems             435
# 2              45                                       none           650
# 3              69                               hip problems           750
# 4              82                                       none           800
# ..            ...                                        ...            ...
# 82             36                     hip problems, dwarfism          1210
# 83              7         fatal stomach bloat, skin problems           608
# 84              5                          eye, hip problems           515
# 85             31                               hip problems          1202
# 86              3  breathing, hip, heart problems, 'dry eye'          2680
#
#    FOOD COSTS PER YEAR    GROOMING FREQUNCY
# 0                 324           Once a week
# 1                 324           Once a week
# 2                 466   Once in a few weeks
# 3                 324           Once a week
# 4                 324           Once a week
# ..                 ...                  ...
# 82                710                 Daily
# 83                710           Once a week
# 84                466                 Daily
# 85                710           Once a week
# 86                466           Once a week
#
# [87 rows x 11 columns]

# %% [markdown]
# ## Encoding all the categorical features into numerical features over here

# %%
for feature in cat_features:
  feature_mapping={category:index for index,category in enumerate(data[feature].unique())}
  data[feature]=data[feature].map(feature_mapping)

# %%
data
# Out:
#     Breed  type  score  popularity ranking  size  intelligence  \
# 0       0     0   3.61                  61     1             0
# 1       1     0   3.53                  48     1             0
# 2       2     1   3.22                  16     2             1
# 3       3     2   3.34                  81     2             0
# 4       4     2   3.33                  51     2             2
# ..    ...   ...    ...                 ...   ...           ...
# 82     82     1   1.82                  47     3             1
# 83     83     6   1.66                  42     3             5
# 84     84     3   1.76                  54     2             5
# 85     85     1   1.95                  41     3             1
# 86     86     3   0.99                   6     2             5
#
#     congential ailments  score for kids  size.1  $LIFETIME COST  \
# 0                     0            4.99       0               0
# 1                     1            4.91       0               1
# 2                     0            4.72       1               2
# 3                     2            4.71       1               3
# 4                     0            4.70       1               4
# ..                  ...             ...     ...             ...
# 82                   44            2.57       2              82
# 83                   45            2.54       2              83
# 84                   37            2.51       1              84
# 85                    2            2.33       2              85
# 86                   46            1.86       1              86
#
#     INTELLIGENCE RANK  INTELLIGENCE %  LONGEVITY(YEARS)  \
# 0                  30               0             14.00
# 1                  35               1             13.84
# 2                  45               2             12.58
# 3                  31               3             12.49
# 4                  18               4             11.66
# ..                ...             ...               ...
# 82                 50              63             10.67
# 83                 75              64              6.75
# 84                 77              65              9.01
# 85                 54              27             10.16
# 86                 78              66              6.29
#
#     NUMBER OF GENETIC AILMENTS  GENETIC AILMENTS  PURCHASE PRICE  \
# 0                            0                 0               0
# 1                            2                 1               1
# 2                            0                 0               2
# 3                            1                 2               3
# 4                            0                 0               4
# ..                         ...               ...             ...
# 82                           2                47              72
# 83                           2                48              73
# 84                           2                40              74
# 85                           1                 2              75
# 86                           5                49              76
#
#     FOOD COSTS PER YEAR  GROOMING FREQUNCY  SUITABILITY FOR CHILDREN
# 0                     0                  0                         1
# 1                     0                  0                         1
# 2                     1                  1                         1
# 3                     0                  0                         1
# 4                     0                  0                         1
# ..                  ...                ...                       ...
# 82                    5                  2                         2
# 83                    5                  0                         2
# 84                    1                  2                         2
# 85                    5                  0                         3
# 86                    1                  0                         2
#
# [87 rows x 19 columns]

# %%
data['LONGEVITY(Yrs)']=data['LONGEVITY(YEARS)']

# %%
data.drop("LONGEVITY(YEARS)",axis=1,inplace=True)

# %% [markdown]
# ## Creating the features and labels over here

# %%
X=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %% [markdown]
# ## Splitting the dataset into training set and testing set to avoid the problem of overfitting over here

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# ## Training the model on the training set over here

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, Ridge,Lasso

# %%
# from sklearn.ensemble import RandomForestRegressor
# from xgboost import XGBRegressor
regressor=Ridge()
regressor.fit(X_train,y_train)
# Out:
# Ridge()

# %%
y_pred=regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1),y_test.reshape(len(y_test),1)),1))
# Out:
# [[13.18 12.58]
#  [12.28 14.42]
#  [13.69 12.63]
#  [10.04 10.34]
#  [ 9.76 10.  ]
#  [12.96 12.87]
#  [12.48 12.28]
#  [10.05 10.  ]
#  [10.55 10.02]
#  [ 8.16  6.29]
#  [12.5  12.54]
#  [12.24 11.81]
#  [12.96 13.51]
#  [ 8.61  8.81]
#  [13.41 12.53]
#  [11.59 11.63]
#  [11.67 11.  ]
#  [11.01 10.1 ]]

# %% [markdown]
# ## Evaluating the performance of the model on the testing dataset over here

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.8016905037245073
