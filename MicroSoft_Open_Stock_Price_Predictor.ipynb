# %% [markdown]
# ## Importing the essential libraries over here

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Importing the dataset over here

# %%
data=pd.read_csv("Microsoft Dataset.csv")

# %%
data.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  1986-03-13  0.088542  0.101563  0.088542  0.097222   0.060055  1031788800
# 1  1986-03-14  0.097222  0.102431  0.097222  0.100694   0.062199   308160000
# 2  1986-03-17  0.100694  0.103299  0.100694  0.102431   0.063272   133171200
# 3  1986-03-18  0.102431  0.103299  0.098958  0.099826   0.061663    67766400
# 4  1986-03-19  0.099826  0.100694  0.097222  0.098090   0.060591    47894400

# %% [markdown]
# ## Taking care of duplicate observations if present over here

# %%
data.drop_duplicates(inplace=True)

# %% [markdown]
# ## Taking care of misssing values if present over here

# %%
data.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# ## Filtering all the numerical features here

# %%
numerical_features=[feature for feature in data.columns if data[feature].dtype!='O']
for feature in numerical_features:
  print(feature)
# Out:
# Open
# High
# Low
# Close
# Adj Close
# Volume

# %%
data[numerical_features]
# Out:
#             Open        High         Low       Close   Adj Close      Volume
# 0       0.088542    0.101563    0.088542    0.097222    0.060055  1031788800
# 1       0.097222    0.102431    0.097222    0.100694    0.062199   308160000
# 2       0.100694    0.103299    0.100694    0.102431    0.063272   133171200
# 3       0.102431    0.103299    0.098958    0.099826    0.061663    67766400
# 4       0.099826    0.100694    0.097222    0.098090    0.060591    47894400
# ...          ...         ...         ...         ...         ...         ...
# 9627  427.190002  431.059998  424.410004  430.160004  430.160004    11845800
# 9628  429.630005  430.820007  426.600006  430.320007  430.320007    15718000
# 9629  425.690002  430.940002  425.690002  429.170013  429.170013    15517100
# 9630  424.299988  424.299988  414.239990  414.670013  414.670013    28394500
# 9631  416.410004  416.630005  404.519989  406.760010  406.760010    17190518
#
# [9632 rows x 6 columns]

# %% [markdown]
# ## Filtering all the categorical features over here

# %%
cat_features=[feature for feature in data.columns if data[feature].dtype=='O']
for feature in cat_features:
  print(feature)
# Out:
# Date

# %% [markdown]
# ## Encoding the categorical feature over here

# %%
data['Date'].value_counts()
# Out:
# Date
# 1986-03-13    1
# 2011-08-18    1
# 2011-08-22    1
# 2011-08-23    1
# 2011-08-24    1
#              ..
# 1998-11-23    1
# 1998-11-24    1
# 1998-11-25    1
# 1998-11-27    1
# 2024-05-31    1
# Name: count, Length: 9632, dtype: int64

# %%
Date_mapping={}
for index,Date in enumerate(data['Date'].unique()):
  Date_mapping[Date]=index
print(Date_mapping)
# Out:
# {'1986-03-13': 0, '1986-03-14': 1, '1986-03-17': 2, '1986-03-18': 3, '1986-03-19': 4, '1986-03-20': 5, '1986-03-21': 6, '1986-03-24': 7, '1986-03-25': 8, '1986-03-26': 9, '1986-03-27': 10, '1986-03-31': 11, '1986-04-01': 12, '1986-04-02': 13, '1986-04-03': 14, '1986-04-04': 15, '1986-04-07': 16, '1986-04-08': 17, '1986-04-09': 18, '1986-04-10': 19, '1986-04-11': 20, '1986-04-14': 21, '1986-04-15': 22, '1986-04-16': 23, '1986-04-17': 24, '1986-04-18': 25, '1986-04-21': 26, '1986-04-22': 27, '1986-04-23': 28, '1986-04-24': 29, '1986-04-25': 30, '1986-04-28': 31, '1986-04-29': 32, '1986-04-30': 33, '1986-05-01': 34, '1986-05-02': 35, '1986-05-05': 36, '1986-05-06': 37, '1986-05-07': 38, '1986-05-08': 39, '1986-05-09': 40, '1986-05-12': 41, '1986-05-13': 42, '1986-05-14': 43, '1986-05-15': 44, '1986-05-16': 45, '1986-05-19': 46, '1986-05-20': 47, '1986-05-21': 48, '1986-05-22': 49, '1986-05-23': 50, '1986-05-27': 51, '1986-05-28': 52, '1986-05-29': 53, '1986-05-30': 54, '1986-06-02': 55, '1986-06-03': 56, '1986-06-04': 57, '1986-06-05': 58, '1986-06-06': 59, '1986-06-09': 60, '1986-06-10': 61, '1986-06-11': 62, '1986-06-12': 63, '1986-06-13': 64, '1986-06-16': 65, '1986-06-17': 66, '1986-06-18': 67, '1986-06-19': 68, '1986-06-20': 69, '1986-06-23': 70, '1986-06-24': 71, '1986-06-25': 72, '1986-06-26': 73, '1986-06-27': 74, '1986-06-30': 75, '1986-07-01': 76, '1986-07-02': 77, '1986-07-03': 78, '1986-07-07': 79, '1986-07-08': 80, '1986-07-09': 81, '1986-07-10': 82, '1986-07-11': 83, '1986-07-14': 84, '1986-07-15': 85, '1986-07-16': 86, '1986-07-17': 87, '1986-07-18': 88, '1986-07-21': 89, '1986-07-22': 90, '1986-07-23': 91, '1986-07-24': 92, '1986-07-25': 93, '1986-07-28': 94, '1986-07-29': 95, '1986-07-30': 96, '1986-07-31': 97, '1986-08-01': 98, '1986-08-04': 99, '1986-08-05': 100, '1986-08-06': 101, '1986-08-07': 102, '1986-08-08': 103, '1986-08-11': 104, '1986-08-12': 105, '1986-08-13': 106, '1986-08-14': 107, '1986-08-15': 108, '1986-08-18': 109, '1986-08-19': 110, '1986-08-20': 111, '1986-08-21': 112, '1986-08-22': 113, '1986-08-25': 114, '1986-08-26': 115, '1986-08-27': 116, '1986-08-28': 117, '1986-08-29': 118, '1986-09-02': 119, '1986-09-03': 120, '1986-09-04': 121, '1986-09-05': 122, '1986-09-08': 123, '1986-09-09': 124, '1986-09-10': 125, '1986-09-11': 126, '1986-09-12': 127, '1986-09-15': 128, '1986-09-16': 129, '1986-09-17': 130, '1986-09-18': 131, '1986-09-19': 132, '1986-09-22': 133, '1986-09-23': 134, '1986-09-24': 135, '1986-09-25': 136, '1986-09-26': 137, '1986-09-29': 138, '1986-09-30': 139, '1986-10-01': 140, '1986-10-02': 141, '1986-10-03': 142, '1986-10-06': 143, '1986-10-07': 144, '1986-10-08': 145, '1986-10-09': 146, '1986-10-10': 147, '1986-10-13': 148, '1986-10-14': 149, '1986-10-15': 150, '1986-10-16': 151, '1986-10-17': 152, '1986-10-20': 153, '1986-10-21': 154, '1986-10-22': 155, '1986-10-23': 156, '1986-10-24': 157, '1986-10-27': 158, '1986-10-28': 159, '1986-10-29': 160, '1986-10-30': 161, '1986-10-31': 162, '1986-11-03': 163, '1986-11-04': 164, '1986-11-05': 165, '1986-11-06': 166, '1986-11-07': 167, '1986-11-10': 168, '1986-11-11': 169, '1986-11-12': 170, '1986-11-13': 171, '1986-11-14': 172, '1986-11-17': 173, '1986-11-18': 174, '1986-11-19': 175, '1986-11-20': 176, '1986-11-21': 177, '1986-11-24': 178, '1986-11-25': 179, '1986-11-26': 180, '1986-11-28': 181, '1986-12-01': 182, '1986-12-02': 183, '1986-12-03': 184, '1986-12-04': 185, '1986-12-05': 186, '1986-12-08': 187, '1986-12-09': 188, '1986-12-10': 189, '1986-12-11': 190, '1986-12-12': 191, '1986-12-15': 192, '1986-12-16': 193, '1986-12-17': 194, '1986-12-18': 195, '1986-12-19': 196, '1986-12-22': 197, '1986-12-23': 198, '1986-12-24': 199, '1986-12-26': 200, '1986-12-29': 201, '1986-12-30': 202, '1986-12-31': 203, '1987-01-02': 204, '1987-01-05': 205, '1987-01-06': 206, '1987-01-07': 207, '1987-01-08': 208, '1987-01-09': 209, '1987-01-12': 210, '1987-01-13': 211, '1987-01-14': 212, '1987-01-15': 213, '1987-01-16': 214, '1987-01-19': 215, '1987 ...

# %%
data['Date']=data['Date'].map(Date_mapping)

# %%
data
# Out:
#       Date        Open        High         Low       Close   Adj Close  \
# 0        0    0.088542    0.101563    0.088542    0.097222    0.060055
# 1        1    0.097222    0.102431    0.097222    0.100694    0.062199
# 2        2    0.100694    0.103299    0.100694    0.102431    0.063272
# 3        3    0.102431    0.103299    0.098958    0.099826    0.061663
# 4        4    0.099826    0.100694    0.097222    0.098090    0.060591
# ...    ...         ...         ...         ...         ...         ...
# 9627  9627  427.190002  431.059998  424.410004  430.160004  430.160004
# 9628  9628  429.630005  430.820007  426.600006  430.320007  430.320007
# 9629  9629  425.690002  430.940002  425.690002  429.170013  429.170013
# 9630  9630  424.299988  424.299988  414.239990  414.670013  414.670013
# 9631  9631  416.410004  416.630005  404.519989  406.760010  406.760010
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9627    11845800
# 9628    15718000
# 9629    15517100
# 9630    28394500
# 9631    17190518
#
# [9632 rows x 7 columns]

# %%
data['OPEN']=data['Open']

# %%
data=data.drop("Open",axis=1)

# %%
data
# Out:
#       Date        High         Low       Close   Adj Close      Volume  \
# 0        0    0.101563    0.088542    0.097222    0.060055  1031788800
# 1        1    0.102431    0.097222    0.100694    0.062199   308160000
# 2        2    0.103299    0.100694    0.102431    0.063272   133171200
# 3        3    0.103299    0.098958    0.099826    0.061663    67766400
# 4        4    0.100694    0.097222    0.098090    0.060591    47894400
# ...    ...         ...         ...         ...         ...         ...
# 9627  9627  431.059998  424.410004  430.160004  430.160004    11845800
# 9628  9628  430.820007  426.600006  430.320007  430.320007    15718000
# 9629  9629  430.940002  425.690002  429.170013  429.170013    15517100
# 9630  9630  424.299988  414.239990  414.670013  414.670013    28394500
# 9631  9631  416.630005  404.519989  406.760010  406.760010    17190518
#
#             OPEN
# 0       0.088542
# 1       0.097222
# 2       0.100694
# 3       0.102431
# 4       0.099826
# ...          ...
# 9627  427.190002
# 9628  429.630005
# 9629  425.690002
# 9630  424.299988
# 9631  416.410004
#
# [9632 rows x 7 columns]

# %% [markdown]
# ## Creating the features and labels over here

# %%
X=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %% [markdown]
# ## Splitting the dataset into training set and testing set over here to avoid the problem of overfitting

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

# Assuming X_train, X_test, y_train, y_test are already defined

# Initialize regressors
regressors = {
    "Random Forest": RandomForestRegressor(),
    "Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(),
    "Lasso Regression": Lasso(),
    "Support Vector Machine": SVR(),
    "K-Nearest Neighbors": KNeighborsRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
    "XGBoost": XGBRegressor(),
}

# Train and evaluate each regressor
results = {}
for name, regressor in regressors.items():
    regressor.fit(X_train, y_train)
    y_pred = regressor.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    results[name] = mse

# Select the regressor with the lowest mean squared error (MSE)
best_regressor = min(results, key=results.get)
lowest_mse = results[best_regressor]

print("Best Regressor:", best_regressor)
print("Mean Squared Error:", lowest_mse)
# Out:
# Best Regressor: Linear Regression
# Mean Squared Error: 0.3131160219460679

# %%
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict((X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_test.reshape(len(y_test),1),y_pred.reshape(len(y_pred),1)),1))
# Out:
# [[29.6  29.41]
#  [ 3.35  3.36]
#  [16.8  16.88]
#  ...
#  [19.81 20.13]
#  [31.89 31.69]
#  [ 2.73  2.73]]

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9999584573022716
