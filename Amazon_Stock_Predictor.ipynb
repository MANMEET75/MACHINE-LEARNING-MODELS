# %% [markdown]
# ## Importing the essential libraries over here

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing the dataset over here

# %%
data=pd.read_csv('AMZN.csv')

# %%
data.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  1997-05-15  2.437500  2.500000  1.927083  1.958333   1.958333  72156000
# 1  1997-05-16  1.968750  1.979167  1.708333  1.729167   1.729167  14700000
# 2  1997-05-19  1.760417  1.770833  1.625000  1.708333   1.708333   6106800
# 3  1997-05-20  1.729167  1.750000  1.635417  1.635417   1.635417   5467200
# 4  1997-05-21  1.635417  1.645833  1.375000  1.427083   1.427083  18853200

# %% [markdown]
# ## Taking care of duplicate observations over here

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Taking care of missing values if present over here

# %%
data.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# ## Filtering all the numerical features over here

# %%
numerical_features=[feature for feature in data.columns if data[feature].dtype!='O']
for feature in numerical_features:
  print(feature)
# Out:
# Open
# High
# Low
# Close
# Adj Close
# Volume

# %%
data[numerical_features]
# Out:
#              Open         High          Low        Close    Adj Close  \
# 0        2.437500     2.500000     1.927083     1.958333     1.958333
# 1        1.968750     1.979167     1.708333     1.729167     1.729167
# 2        1.760417     1.770833     1.625000     1.708333     1.708333
# 3        1.729167     1.750000     1.635417     1.635417     1.635417
# 4        1.635417     1.645833     1.375000     1.427083     1.427083
# ...           ...          ...          ...          ...          ...
# 6252  3136.260010  3231.879883  3120.219971  3225.010010  3225.010010
# 6253  3222.419922  3261.679932  3191.060059  3229.830078  3229.830078
# 6254  3236.110107  3323.340088  3233.979980  3297.780029  3297.780029
# 6255  3274.100098  3327.399902  3253.739990  3268.159912  3268.159912
# 6256  3274.989990  3282.370117  3201.000000  3272.989990  3272.989990
#
#         Volume
# 0     72156000
# 1     14700000
# 2      6106800
# 3      5467200
# 4     18853200
# ...        ...
# 6252   5141300
# 6253   3326900
# 6254   3204300
# 6255   2790600
# 6256   2834900
#
# [6257 rows x 6 columns]

# %% [markdown]
# ## Filtering all the categorical features over here

# %%
cat_features=[feature for feature in data.columns if data[feature].dtype=='O']
for feature in cat_features:
  print(feature)
# Out:
# Date

# %%
data[cat_features]
# Out:
#             Date
# 0     1997-05-15
# 1     1997-05-16
# 2     1997-05-19
# 3     1997-05-20
# 4     1997-05-21
# ...          ...
# 6252  2022-03-18
# 6253  2022-03-21
# 6254  2022-03-22
# 6255  2022-03-23
# 6256  2022-03-24
#
# [6257 rows x 1 columns]

# %% [markdown]
# ## Encoding the categorical features over here

# %%
for feature in cat_features:
  feature_mapping={category:index for index,category in enumerate(data[feature].unique())}
  data[feature]=data[feature].map(feature_mapping)

# %%
data
# Out:
#       Date         Open         High          Low        Close    Adj Close  \
# 0        0     2.437500     2.500000     1.927083     1.958333     1.958333
# 1        1     1.968750     1.979167     1.708333     1.729167     1.729167
# 2        2     1.760417     1.770833     1.625000     1.708333     1.708333
# 3        3     1.729167     1.750000     1.635417     1.635417     1.635417
# 4        4     1.635417     1.645833     1.375000     1.427083     1.427083
# ...    ...          ...          ...          ...          ...          ...
# 6252  6252  3136.260010  3231.879883  3120.219971  3225.010010  3225.010010
# 6253  6253  3222.419922  3261.679932  3191.060059  3229.830078  3229.830078
# 6254  6254  3236.110107  3323.340088  3233.979980  3297.780029  3297.780029
# 6255  6255  3274.100098  3327.399902  3253.739990  3268.159912  3268.159912
# 6256  6256  3274.989990  3282.370117  3201.000000  3272.989990  3272.989990
#
#         Volume
# 0     72156000
# 1     14700000
# 2      6106800
# 3      5467200
# 4     18853200
# ...        ...
# 6252   5141300
# 6253   3326900
# 6254   3204300
# 6255   2790600
# 6256   2834900
#
# [6257 rows x 7 columns]

# %% [markdown]
# ## Creating the features and labels over here

# %%
data['OPEN']=data['Open']
data.drop(['Open'],axis=1,inplace=True)

# %%
X=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %% [markdown]
# ## Splitting the dataset into training set and testing set over here to avoid the problem of overfitting

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# ## Training the model on the training dataset over here

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(n_estimators=10,random_state=0)
regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %% [markdown]
# ## Evaluating the performance of the model on the testing dataset over here

# %%
y_pred=regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1),y_test.reshape(len(y_test),1)),1))
# Out:
# [[  15.83   16.2 ]
#  [3123.34 3127.89]
#  [ 957.56  960.11]
#  ...
#  [  32.99   33.15]
#  [  82.92   83.24]
#  [ 955.72  964.  ]]

# %% [markdown]
# ## Checking the metrics of the model over here

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9998241469686423
