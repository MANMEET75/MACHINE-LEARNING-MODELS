# %% [markdown]
# ## Importing the essential libraries over here

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.float_format', lambda x: "{:.6f}".format(x) if not pd.isna(x) else "NaN")

# %% [markdown]
# ## Importing the dataset over here

# %%
data=pd.read_csv("t20_batting.csv")

# %%
data.head()
# Out:
#        id       span  matches   innings   not_out       runs high_score  \
# 0  420402  2013-2022        2  2.000000  0.000000  33.000000         24
# 1  921509  2019-2022       16 16.000000  3.000000 381.000000        64*
# 2  568136  2016-2022       22  3.000000  3.000000  27.000000        24*
# 3  352048  2012-2022       55 45.000000 13.000000 615.000000        56*
# 4  440970  2013-2022        6  4.000000  2.000000  48.000000         36
#
#    average_score  ball_faced  strike_rate     100s       50       0s  \
# 0      16.500000   45.000000    73.330000 0.000000 0.000000 0.000000
# 1      29.300000  361.000000   105.540000 0.000000 1.000000 0.000000
# 2            NaN   24.000000   112.500000 0.000000 0.000000 0.000000
# 3      19.210000  509.000000   120.820000 0.000000 1.000000 3.000000
# 4      24.000000   55.000000    87.270000 0.000000 0.000000 0.000000
#
#          4s        6s
# 0  1.000000  1.000000
# 1 30.000000 10.000000
# 2  4.000000  0.000000
# 3 45.000000 27.000000
# 4  5.000000  0.000000

# %%
data.shape
# Out:
# (327, 15)

# %% [markdown]
# In this particular usecase I want to predict the runs over here

# %% [markdown]
# ## Taking care of duplicate observations if present over here

# %%
data.drop_duplicates(inplace=True)

# %% [markdown]
# ## Taking care of missing values if present over here

# %%
data.isnull().sum()
# Out:
# id                0
# span             17
# matches           0
# innings          10
# not_out          10
# runs             10
# high_score       10
# average_score    26
# ball_faced       10
# strike_rate      10
# 100s             10
# 50               10
# 0s               10
# 4s               10
# 6s               10
# dtype: int64

# %%
missing_values=[feature for feature in data.columns if data[feature].isnull().sum()>1]
for feature in missing_values:
  print(feature)
# Out:
# span
# innings
# not_out
# runs
# high_score
# average_score
# ball_faced
# strike_rate
# 100s
# 50
# 0s
# 4s
# 6s

# %%
data[missing_values]
# Out:
#           span   innings   not_out       runs high_score  average_score  \
# 0    2013-2022  2.000000  0.000000  33.000000         24      16.500000
# 1    2019-2022 16.000000  3.000000 381.000000        64*      29.300000
# 2    2016-2022  3.000000  3.000000  27.000000        24*            NaN
# 3    2012-2022 45.000000 13.000000 615.000000        56*      19.210000
# 4    2013-2022  4.000000  2.000000  48.000000         36      24.000000
# ..         ...       ...       ...        ...        ...            ...
# 322  2020-2022  9.000000  4.000000 198.000000        44*      39.600000
# 323  2021-2021  2.000000  1.000000   3.000000          3       3.000000
# 324  2018-2022 17.000000  5.000000 162.000000        27*      13.500000
# 325  2009-2022  8.000000  2.000000  51.000000        31*       8.500000
# 326  2019-2022 17.000000  7.000000 150.000000         28      15.000000
#
#      ball_faced  strike_rate     100s       50       0s        4s        6s
# 0     45.000000    73.330000 0.000000 0.000000 0.000000  1.000000  1.000000
# 1    361.000000   105.540000 0.000000 1.000000 0.000000 30.000000 10.000000
# 2     24.000000   112.500000 0.000000 0.000000 0.000000  4.000000  0.000000
# 3    509.000000   120.820000 0.000000 1.000000 3.000000 45.000000 27.000000
# 4     55.000000    87.270000 0.000000 0.000000 0.000000  5.000000  0.000000
# ..          ...          ...      ...      ...      ...       ...       ...
# 322  133.000000   148.870000 0.000000 0.000000 0.000000  7.000000 17.000000
# 323    9.000000    33.330000 0.000000 0.000000 0.000000  0.000000  0.000000
# 324  116.000000   139.650000 0.000000 0.000000 2.000000 12.000000 10.000000
# 325   54.000000    94.440000 0.000000 0.000000 0.000000  4.000000  2.000000
# 326  155.000000    96.770000 0.000000 0.000000 2.000000  9.000000  5.000000
#
# [327 rows x 13 columns]

# %% [markdown]
# ## Filtering only the numerical values over here

# %%
numeric_features=[feature for feature in data.columns if data[feature].dtype!='O']
for feature in numeric_features:
  print(feature)
# Out:
# id
# matches
# innings
# not_out
# runs
# average_score
# ball_faced
# strike_rate
# 100s
# 50
# 0s
# 4s
# 6s

# %%
data[numeric_features]
# Out:
#           id  matches   innings   not_out       runs  average_score  \
# 0     420402        2  2.000000  0.000000  33.000000      16.500000
# 1     921509       16 16.000000  3.000000 381.000000      29.300000
# 2     568136       22  3.000000  3.000000  27.000000            NaN
# 3     352048       55 45.000000 13.000000 615.000000      19.210000
# 4     440970        6  4.000000  2.000000  48.000000      24.000000
# ..       ...      ...       ...       ...        ...            ...
# 322   677077       23  9.000000  4.000000 198.000000      39.600000
# 323  1206110        6  2.000000  1.000000   3.000000       3.000000
# 324   820691       24 17.000000  5.000000 162.000000      13.500000
# 325   248920       12  8.000000  2.000000  51.000000       8.500000
# 326   443263       38 17.000000  7.000000 150.000000      15.000000
#
#      ball_faced  strike_rate     100s       50       0s        4s        6s
# 0     45.000000    73.330000 0.000000 0.000000 0.000000  1.000000  1.000000
# 1    361.000000   105.540000 0.000000 1.000000 0.000000 30.000000 10.000000
# 2     24.000000   112.500000 0.000000 0.000000 0.000000  4.000000  0.000000
# 3    509.000000   120.820000 0.000000 1.000000 3.000000 45.000000 27.000000
# 4     55.000000    87.270000 0.000000 0.000000 0.000000  5.000000  0.000000
# ..          ...          ...      ...      ...      ...       ...       ...
# 322  133.000000   148.870000 0.000000 0.000000 0.000000  7.000000 17.000000
# 323    9.000000    33.330000 0.000000 0.000000 0.000000  0.000000  0.000000
# 324  116.000000   139.650000 0.000000 0.000000 2.000000 12.000000 10.000000
# 325   54.000000    94.440000 0.000000 0.000000 0.000000  4.000000  2.000000
# 326  155.000000    96.770000 0.000000 0.000000 2.000000  9.000000  5.000000
#
# [327 rows x 13 columns]

# %% [markdown]
# ## Filtering only the categorical features over here

# %%
cat_features=[feature for feature in data.columns if data[feature].dtype=='O']
for feature in cat_features:
  print(feature)
# Out:
# span
# high_score

# %%
data[cat_features]
# Out:
#           span high_score
# 0    2013-2022         24
# 1    2019-2022        64*
# 2    2016-2022        24*
# 3    2012-2022        56*
# 4    2013-2022         36
# ..         ...        ...
# 322  2020-2022        44*
# 323  2021-2021          3
# 324  2018-2022        27*
# 325  2009-2022        31*
# 326  2019-2022         28
#
# [327 rows x 2 columns]

# %% [markdown]
# ## Observation: that the high score is not a categorial variable over here so therefore we need to preprocess it

# %%
data['high_score']=data['high_score'].str.replace("*","")

# %%
data['high_score']=pd.to_numeric(data['high_score'])

# %%
cat_features=[feature for feature in data.columns if data[feature].dtype=='O']
for feature in cat_features:
  print(feature)
# Out:
# span

# %%
data[cat_features]
# Out:
#           span
# 0    2013-2022
# 1    2019-2022
# 2    2016-2022
# 3    2012-2022
# 4    2013-2022
# ..         ...
# 322  2020-2022
# 323  2021-2021
# 324  2018-2022
# 325  2009-2022
# 326  2019-2022
#
# [327 rows x 1 columns]

# %% [markdown]
# ## Dropping all the missing values over here

# %%
data.dropna(inplace=True)

# %%
data.drop("id",axis=1,inplace=True)

# %% [markdown]
# ## Over here the feature having name Id does not make any sense so therefore we are directly dropping them

# %%
data['span'].value_counts()
# Out:
# span
# 2016-2022    20
# 2019-2022    20
# 2018-2022    17
# 2015-2022    17
# 2017-2022    16
# 2022-2022    16
# 2014-2022    14
# 2021-2022    12
# 2021-2023    11
# 2011-2022    11
# 2019-2023    10
# 2015-2023     9
# 2012-2022     9
# 2009-2022     8
# 2010-2022     8
# 2020-2022     8
# 2021-2021     6
# 2013-2022     6
# 2017-2023     5
# 2019-2021     5
# 2018-2021     4
# 2016-2023     4
# 2008-2022     3
# 2019-2019     3
# 2017-2021     3
# 2020-2023     3
# 2006-2022     3
# 2010-2023     3
# 2006-2020     2
# 2012-2021     2
# 2022-2023     2
# 2017-2017     2
# 2023-2023     2
# 2011-2021     2
# 2014-2023     2
# 2007-2022     2
# 2016-2021     2
# 2012-2016     1
# 2020-2020     1
# 2010-2021     1
# 2012-2019     1
# 2006-2023     1
# 2007-2020     1
# 2018-2018     1
# 2013-2019     1
# 2007-2010     1
# 2020-2021     1
# 2016-2016     1
# 2007-2009     1
# 2006-2014     1
# 2009-2021     1
# 2011-2019     1
# 2014-2017     1
# 2018-2023     1
# 2012-2014     1
# 2011-2012     1
# Name: count, dtype: int64

# %%
span_mapping={}

# Iterate over the lsit of spans and assign a sequential number using for loop
for index,span in enumerate(['2016-2022','2019-2022','2018-2022','2015-2022','2017-2022', '2022-2022','2014-2022','2021-2022','2021-2023',
 '2011-2022',
 '2019-2023',
 '2015-2023',
 '2012-2022',
 '2009-2022',
 '2010-2022',
 '2020-2022',
 '2021-2021',
 '2013-2022',
 '2017-2023',
 '2019-2021',
 '2018-2021',
 '2016-2023',
 '2008-2022',
 '2019-2019',
 '2017-2021',
 '2020-2023',
 '2006-2022',
 '2010-2023',
 '2006-2020',
 '2012-2021',
 '2022-2023',
 '2017-2017',
 '2023-2023',
 '2011-2021',
 '2014-2023',
 '2007-2022',
 '2016-2021',
 '2012-2016',
 '2020-2020',
 '2010-2021',
 '2012-2019',
 '2006-2023',
 '2007-2020',
 '2018-2018',
 '2013-2019',
 '2007-2010',
 '2020-2021',
 '2016-2016',
 '2007-2009',
 '2006-2014',
 '2009-2021',
 '2011-2019',
 '2014-2017',
 '2018-2023',
 '2012-2014',
 '2011-2012']):
    span_mapping[span]=index
print(span_mapping)
# Out:
# {'2016-2022': 0, '2019-2022': 1, '2018-2022': 2, '2015-2022': 3, '2017-2022': 4, '2022-2022': 5, '2014-2022': 6, '2021-2022': 7, '2021-2023': 8, '2011-2022': 9, '2019-2023': 10, '2015-2023': 11, '2012-2022': 12, '2009-2022': 13, '2010-2022': 14, '2020-2022': 15, '2021-2021': 16, '2013-2022': 17, '2017-2023': 18, '2019-2021': 19, '2018-2021': 20, '2016-2023': 21, '2008-2022': 22, '2019-2019': 23, '2017-2021': 24, '2020-2023': 25, '2006-2022': 26, '2010-2023': 27, '2006-2020': 28, '2012-2021': 29, '2022-2023': 30, '2017-2017': 31, '2023-2023': 32, '2011-2021': 33, '2014-2023': 34, '2007-2022': 35, '2016-2021': 36, '2012-2016': 37, '2020-2020': 38, '2010-2021': 39, '2012-2019': 40, '2006-2023': 41, '2007-2020': 42, '2018-2018': 43, '2013-2019': 44, '2007-2010': 45, '2020-2021': 46, '2016-2016': 47, '2007-2009': 48, '2006-2014': 49, '2009-2021': 50, '2011-2019': 51, '2014-2017': 52, '2018-2023': 53, '2012-2014': 54, '2011-2012': 55}

# %%
data['span']=data['span'].map(span_mapping)

# %% [markdown]
# ## Creating the features and labels over here

# %%
data.columns
# Out:
# Index(['span', 'matches', 'innings', 'not_out', 'runs', 'high_score',
#        'average_score', 'ball_faced', 'strike_rate', '100s', '50', '0s', '4s',
#        '6s'],
#       dtype='object')

# %%
X=data.drop(['runs'],axis=1).values
y=data['runs'].values

# %%
X
# Out:
# array([[17.,  2.,  2., ...,  0.,  1.,  1.],
#        [ 1., 16., 16., ...,  0., 30., 10.],
#        [12., 55., 45., ...,  3., 45., 27.],
#        ...,
#        [ 2., 24., 17., ...,  2., 12., 10.],
#        [13., 12.,  8., ...,  0.,  4.,  2.],
#        [ 1., 38., 17., ...,  2.,  9.,  5.]])

# %% [markdown]
# ## Splitting the dataset into training set and testing set over here

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# ## Training the model on the training set over here

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor()
regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## Predicting the results on the testing dataset over here

# %%
y_pred=regressor.predict((X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_test.reshape(len(y_test),1),y_pred.reshape(len(y_pred),1)),1))
# Out:
# [[2.16e+02 2.21e+02]
#  [8.90e+02 8.63e+02]
#  [2.24e+03 2.17e+03]
#  [2.15e+03 1.92e+03]
#  [2.00e+00 5.15e+00]
#  [3.85e+02 3.99e+02]
#  [6.82e+02 6.61e+02]
#  [2.20e+02 2.25e+02]
#  [1.04e+03 9.13e+02]
#  [8.15e+02 1.01e+03]
#  [1.00e+00 4.15e+00]
#  [3.28e+02 3.09e+02]
#  [1.39e+02 1.35e+02]
#  [3.85e+02 3.81e+02]
#  [8.00e+00 1.10e+01]
#  [1.80e+01 1.76e+01]
#  [1.04e+03 1.05e+03]
#  [1.13e+02 1.16e+02]
#  [1.20e+01 1.45e+01]
#  [2.70e+01 3.35e+01]
#  [5.30e+02 5.77e+02]
#  [2.91e+02 3.10e+02]
#  [1.37e+03 1.37e+03]
#  [1.52e+03 1.43e+03]
#  [2.89e+03 3.00e+03]
#  [7.97e+02 8.16e+02]
#  [0.00e+00 2.51e+00]
#  [2.41e+02 2.40e+02]
#  [2.90e+01 3.08e+01]
#  [2.41e+02 2.34e+02]
#  [3.95e+02 4.01e+02]
#  [1.00e+01 1.01e+01]
#  [1.49e+02 1.77e+02]
#  [9.40e+01 9.62e+01]
#  [2.64e+03 2.64e+03]
#  [4.30e+01 4.08e+01]
#  [1.07e+02 1.25e+02]
#  [1.33e+03 1.32e+03]
#  [1.48e+03 1.40e+03]
#  [8.03e+02 6.84e+02]
#  [9.77e+02 1.04e+03]
#  [3.62e+02 3.89e+02]
#  [1.91e+03 1.87e+03]
#  [3.68e+02 3.58e+02]
#  [8.26e+02 8.48e+02]
#  [5.00e+00 6.41e+00]
#  [6.35e+02 6.70e+02]
#  [8.70e+01 7.93e+01]
#  [7.60e+01 6.59e+01]
#  [9.50e+01 9.51e+01]
#  [2.61e+02 2.37e+02]
#  [2.01e+02 1.90e+02]
#  [3.50e+01 2.90e+01]
#  [4.30e+01 3.50e+01]
#  [1.57e+03 1.45e+03]
#  [1.32e+02 1.34e+02]
#  [9.40e+01 8.26e+01]
#  [1.76e+03 1.96e+03]
#  [0.00e+00 2.67e+00]]

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9927224874912746

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
# Out:
# 61.30989376015388

# %%
rmse
# Out:
# 61.30989376015388

# %%
mse
# Out:
# 3758.9030728813555

# %%
actual_vs_predicted = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(actual_vs_predicted)
# Out:
#         Actual   Predicted
# 0   216.000000  220.870000
# 1   890.000000  862.790000
# 2  2243.000000 2174.420000
# 3  2147.000000 1918.500000
# 4     2.000000    5.150000
# 5   385.000000  398.830000
# 6   682.000000  661.000000
# 7   220.000000  225.250000
# 8  1044.000000  912.930000
# 9   815.000000 1005.670000
# 10    1.000000    4.150000
# 11  328.000000  308.630000
# 12  139.000000  135.350000
# 13  385.000000  381.310000
# 14    8.000000   11.030000
# 15   18.000000   17.620000
# 16 1044.000000 1045.460000
# 17  113.000000  116.390000
# 18   12.000000   14.470000
# 19   27.000000   33.510000
# 20  530.000000  576.550000
# 21  291.000000  310.220000
# 22 1369.000000 1373.300000
# 23 1522.000000 1428.090000
# 24 2894.000000 3001.040000
# 25  797.000000  816.300000
# 26    0.000000    2.510000
# 27  241.000000  240.370000
# 28   29.000000   30.780000
# 29  241.000000  233.970000
# 30  395.000000  401.430000
# 31   10.000000   10.080000
# 32  149.000000  176.920000
# 33   94.000000   96.160000
# 34 2635.000000 2644.430000
# 35   43.000000   40.780000
# 36  107.000000  124.730000
# 37 1328.000000 1315.450000
# 38 1482.000000 1401.920000
# 39  803.000000  683.790000
# 40  977.000000 1039.510000
# 41  362.000000  389.290000
# 42 1909.000000 1871.850000
# 43  368.000000  358.320000
# 44  826.000000  847.590000
# 45    5.000000    6.410000
# 46  635.000000  669.880000
# 47   87.000000   79.310000
# 48   76.000000   65.930000
# 49   95.000000   95.110000
# 50  261.000000  236.970000
# 51  201.000000  189.910000
# 52   35.000000   29.010000
# 53   43.000000   35.040000
# 54 1569.000000 1453.190000
# 55  132.000000  133.550000
# 56   94.000000   82.630000
# 57 1758.000000 1962.470000
# 58    0.000000    2.670000

# %%
actual_vs_predicted['Absolute Difference'] = abs(actual_vs_predicted['Actual'] - actual_vs_predicted['Predicted'])

# %%
actual_vs_predicted
# Out:
#         Actual   Predicted  Absolute Difference
# 0   216.000000  220.870000             4.870000
# 1   890.000000  862.790000            27.210000
# 2  2243.000000 2174.420000            68.580000
# 3  2147.000000 1918.500000           228.500000
# 4     2.000000    5.150000             3.150000
# 5   385.000000  398.830000            13.830000
# 6   682.000000  661.000000            21.000000
# 7   220.000000  225.250000             5.250000
# 8  1044.000000  912.930000           131.070000
# 9   815.000000 1005.670000           190.670000
# 10    1.000000    4.150000             3.150000
# 11  328.000000  308.630000            19.370000
# 12  139.000000  135.350000             3.650000
# 13  385.000000  381.310000             3.690000
# 14    8.000000   11.030000             3.030000
# 15   18.000000   17.620000             0.380000
# 16 1044.000000 1045.460000             1.460000
# 17  113.000000  116.390000             3.390000
# 18   12.000000   14.470000             2.470000
# 19   27.000000   33.510000             6.510000
# 20  530.000000  576.550000            46.550000
# 21  291.000000  310.220000            19.220000
# 22 1369.000000 1373.300000             4.300000
# 23 1522.000000 1428.090000            93.910000
# 24 2894.000000 3001.040000           107.040000
# 25  797.000000  816.300000            19.300000
# 26    0.000000    2.510000             2.510000
# 27  241.000000  240.370000             0.630000
# 28   29.000000   30.780000             1.780000
# 29  241.000000  233.970000             7.030000
# 30  395.000000  401.430000             6.430000
# 31   10.000000   10.080000             0.080000
# 32  149.000000  176.920000            27.920000
# 33   94.000000   96.160000             2.160000
# 34 2635.000000 2644.430000             9.430000
# 35   43.000000   40.780000             2.220000
# 36  107.000000  124.730000            17.730000
# 37 1328.000000 1315.450000            12.550000
# 38 1482.000000 1401.920000            80.080000
# 39  803.000000  683.790000           119.210000
# 40  977.000000 1039.510000            62.510000
# 41  362.000000  389.290000            27.290000
# 42 1909.000000 1871.850000            37.150000
# 43  368.000000  358.320000             9.680000
# 44  826.000000  847.590000            21.590000
# 45    5.000000    6.410000             1.410000
# 46  635.000000  669.880000            34.880000
# 47   87.000000   79.310000             7.690000
# 48   76.000000   65.930000            10.070000
# 49   95.000000   95.110000             0.110000
# 50  261.000000  236.970000            24.030000
# 51  201.000000  189.910000            11.090000
# 52   35.000000   29.010000             5.990000
# 53   43.000000   35.040000             7.960000
# 54 1569.000000 1453.190000           115.810000
# 55  132.000000  133.550000             1.550000
# 56   94.000000   82.630000            11.370000
# 57 1758.000000 1962.470000           204.470000
# 58    0.000000    2.670000             2.670000
