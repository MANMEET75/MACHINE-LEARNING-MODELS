# %% [markdown]
# ## Importing the essential libraries over here

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Importing the dataset over here

# %%
data=pd.read_csv("National_Stock_Exchange_of_India_Ltd.csv")

# %%
data.head()
# Out:
#        Symbol       Open       High        Low        LTP    Chng  % Chng  \
# 0  ADANIPORTS        750        766     713.25        715  -47.45   -6.22
# 1  ASIANPAINT   3,101.00   3,167.35   3,091.00   3,138.00   -6.25   -0.20
# 2    AXISBANK        669      674.9     660.45        661  -18.90   -2.78
# 3  BAJAJ-AUTO   3,370.00   3,383.50   3,320.00   3,335.00  -56.70   -1.67
# 4  BAJAJFINSV  17,200.00  17,237.20  16,610.00  16,684.00 -684.85   -3.94
#
#    Volume (lacs) Turnover (crs.)      52w H     52w L  365 d % chng  \
# 0          72.20          532.63        901     384.4         79.22
# 1          10.29          322.53   3,505.00  2,117.15         45.66
# 2         102.53             684      866.9     568.4         10.19
# 3           3.42          114.59   4,361.40  3,041.00          9.30
# 4           3.42          576.79  19,325.00  8,273.70         91.38
#
#    30 d % chng
# 0        -4.65
# 1         5.66
# 2       -21.49
# 3       -12.05
# 4        -9.10

# %% [markdown]
# ## Taking care of missing values if present over here

# %%
data.isnull().sum()
# Out:
# Symbol             0
# Open               0
# High               0
# Low                0
# LTP                0
# Chng               0
# % Chng             0
# Volume (lacs)      0
# Turnover (crs.)    0
# 52w H              0
# 52w L              0
# 365 d % chng       0
# 30 d % chng        0
# dtype: int64

# %% [markdown]
# ## Taking care of duplicate observations if present over here

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Filtering all the numerical features over here

# %%
numerical_features=[feature for feature in data.columns if data[feature].dtype!="O"]
for feature in numerical_features:
  print(feature)
# Out:
# Chng
# % Chng
# Volume (lacs)
# 365 d % chng
# 30 d % chng

# %%
data[numerical_features].head()
# Out:
#      Chng  % Chng  Volume (lacs)  365 d % chng  30 d % chng
# 0  -47.45   -6.22          72.20         79.22        -4.65
# 1   -6.25   -0.20          10.29         45.66         5.66
# 2  -18.90   -2.78         102.53         10.19       -21.49
# 3  -56.70   -1.67           3.42          9.30       -12.05
# 4 -684.85   -3.94           3.42         91.38        -9.10

# %% [markdown]
# ## Filtering all the categorical features over here

# %%
cat_features=[feature for feature in data.columns if data[feature].dtype=="O"]
for feature in cat_features:
  print(feature)
# Out:
# Symbol
# Open
# High
# Low
# LTP
# Turnover (crs.)
# 52w H
# 52w L

# %%
data[cat_features].head()
# Out:
#        Symbol       Open       High        Low        LTP Turnover (crs.)  \
# 0  ADANIPORTS        750        766     713.25        715          532.63
# 1  ASIANPAINT   3,101.00   3,167.35   3,091.00   3,138.00          322.53
# 2    AXISBANK        669      674.9     660.45        661             684
# 3  BAJAJ-AUTO   3,370.00   3,383.50   3,320.00   3,335.00          114.59
# 4  BAJAJFINSV  17,200.00  17,237.20  16,610.00  16,684.00          576.79
#
#        52w H     52w L
# 0        901     384.4
# 1   3,505.00  2,117.15
# 2      866.9     568.4
# 3   4,361.40  3,041.00
# 4  19,325.00  8,273.70

# %%
data['Open']=data['Open'].str.replace(",","")
data['High']=data['High'].str.replace(",","")
data['Low']=data['Low'].str.replace(",","")
data['LTP']=data['LTP'].str.replace(",","")
data['Turnover (crs.)']=data['Turnover (crs.)'].str.replace(",","")
data['52w H']=data['52w H'].str.replace(",","")
data['52w L']=data['52w L'].str.replace(",","")

# %%
data['Open']=pd.to_numeric(data['Open'])
data['High']=pd.to_numeric(data['High'])
data['Low']=pd.to_numeric(data['Low'])
data['LTP']=pd.to_numeric(data['LTP'])
data['Turnover (crs.)']=pd.to_numeric(data['Turnover (crs.)'])
data['52w H']=pd.to_numeric(data['52w H'])
data['52w L']=pd.to_numeric(data['52w L'])

# %%
cat_features=[feature for feature in data.columns if data[feature].dtype=="O"]
for feature in cat_features:
  print(feature)
# Out:
# Symbol

# %%
data.head()
# Out:
#        Symbol     Open      High       Low      LTP    Chng  % Chng  \
# 0  ADANIPORTS    750.0    766.00    713.25    715.0  -47.45   -6.22
# 1  ASIANPAINT   3101.0   3167.35   3091.00   3138.0   -6.25   -0.20
# 2    AXISBANK    669.0    674.90    660.45    661.0  -18.90   -2.78
# 3  BAJAJ-AUTO   3370.0   3383.50   3320.00   3335.0  -56.70   -1.67
# 4  BAJAJFINSV  17200.0  17237.20  16610.00  16684.0 -684.85   -3.94
#
#    Volume (lacs)  Turnover (crs.)    52w H    52w L  365 d % chng  30 d % chng
# 0          72.20           532.63    901.0   384.40         79.22        -4.65
# 1          10.29           322.53   3505.0  2117.15         45.66         5.66
# 2         102.53           684.00    866.9   568.40         10.19       -21.49
# 3           3.42           114.59   4361.4  3041.00          9.30       -12.05
# 4           3.42           576.79  19325.0  8273.70         91.38        -9.10

# %%
data.shape
# Out:
# (50, 13)

# %% [markdown]
# ## Encoding the categorical features into numerical features over here

# %%
for feature in cat_features:
  feature_mapping={category:index for index,category in enumerate(data[feature].unique())}
  data[feature]=data[feature].map(feature_mapping)

# %% [markdown]
# ## Creating the features and labels over here

# %%
data['OPEN']=data['Open']
data.drop('Open',axis=1,inplace=True)

# %%
X=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %%
X.shape
# Out:
# (50, 12)

# %% [markdown]
# ## Splitting the dataset into training set and testing set to avoid the problem of overfitting over here

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# ## Training the model on the training dataset over here

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(n_estimators=100,random_state=0)
regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %% [markdown]
# ## Evaluating the performance of the model on the testing dataset

# %%
y_pred=regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1),y_test.reshape(len(y_test),1)),1))
# Out:
# [[ 1897.1   2002.  ]
#  [ 4191.83  4770.  ]
#  [  196.44   157.75]
#  [  761.34   800.2 ]
#  [  695.54   669.  ]
#  [  655.19   668.25]
#  [  383.2    486.25]
#  [ 6341.89  7520.  ]
#  [  740.57   739.  ]
#  [13557.53 17200.  ]]

# %% [markdown]
# ## Printing the R2 Score over here

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.942004797655232
