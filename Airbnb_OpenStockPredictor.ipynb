# %% [markdown]
# ## Importing the essential libraries over here

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Importing the dataset over here

# %%
data=pd.read_csv("abnb_stock_data.csv")

# %%
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2020-12-10  146.000000  165.000000  141.250000  144.710007  144.710007
# 1  2020-12-11  146.550003  151.500000  135.100006  139.250000  139.250000
# 2  2020-12-14  135.000000  135.300003  125.160004  130.000000  130.000000
# 3  2020-12-15  126.690002  127.599998  121.500000  124.800003  124.800003
# 4  2020-12-16  125.830002  142.000000  124.910004  137.990005  137.990005
#
#      Volume
# 0  70447500
# 1  26980800
# 2  16966100
# 3  10914400
# 4  20409600

# %% [markdown]
# ## Taking care of duplicate observations if present over here

# %%
data.drop_duplicates(inplace=True)

# %% [markdown]
# ## Taking care of misssing values if present over here

# %%
data.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
missing_values=[feature for feature in data.columns if data[feature].isnull().sum()>1]
for feature in missing_values:
  print(feature)

# %% [markdown]
# ## Filtering all the numerical features here

# %%
numerical_features=[feature for feature in data.columns if data[feature].dtype!='O']
for feature in numerical_features:
  print(feature)
# Out:
# Open
# High
# Low
# Close
# Adj Close
# Volume

# %%
data[numerical_features]
# Out:
#            Open        High         Low       Close   Adj Close    Volume
# 0    146.000000  165.000000  141.250000  144.710007  144.710007  70447500
# 1    146.550003  151.500000  135.100006  139.250000  139.250000  26980800
# 2    135.000000  135.300003  125.160004  130.000000  130.000000  16966100
# 3    126.690002  127.599998  121.500000  124.800003  124.800003  10914400
# 4    125.830002  142.000000  124.910004  137.990005  137.990005  20409600
# ..          ...         ...         ...         ...         ...       ...
# 804  153.270004  155.300003  150.824997  152.660004  152.660004   4851100
# 805  149.960007  150.179993  148.559998  149.270004  149.270004   5277900
# 806  150.000000  152.470001  149.229996  152.059998  152.059998   4623700
# 807  152.029999  154.899994  151.789993  153.429993  153.429993   4329100
# 808  153.399994  160.000000  153.220001  157.470001  157.470001   8002300
#
# [809 rows x 6 columns]

# %% [markdown]
# ## Filtering all the categorical features over here

# %%
cat_features=[feature for feature in data.columns if data[feature].dtype=='O']
for feature in cat_features:
  print(feature)
# Out:
# Date

# %% [markdown]
# ## Encoding the categorical feature over here

# %%
data['Date'].value_counts()
# Out:
# Date
# 2020-12-10    1
# 2023-02-08    1
# 2023-01-25    1
# 2023-01-26    1
# 2023-01-27    1
#              ..
# 2022-01-11    1
# 2022-01-12    1
# 2022-01-13    1
# 2022-01-14    1
# 2024-02-29    1
# Name: count, Length: 809, dtype: int64

# %%
Date_mapping={}
for index,Date in enumerate(data['Date'].unique()):
  Date_mapping[Date]=index
print(Date_mapping)
# Out:
# {'2020-12-10': 0, '2020-12-11': 1, '2020-12-14': 2, '2020-12-15': 3, '2020-12-16': 4, '2020-12-17': 5, '2020-12-18': 6, '2020-12-21': 7, '2020-12-22': 8, '2020-12-23': 9, '2020-12-24': 10, '2020-12-28': 11, '2020-12-29': 12, '2020-12-30': 13, '2020-12-31': 14, '2021-01-04': 15, '2021-01-05': 16, '2021-01-06': 17, '2021-01-07': 18, '2021-01-08': 19, '2021-01-11': 20, '2021-01-12': 21, '2021-01-13': 22, '2021-01-14': 23, '2021-01-15': 24, '2021-01-19': 25, '2021-01-20': 26, '2021-01-21': 27, '2021-01-22': 28, '2021-01-25': 29, '2021-01-26': 30, '2021-01-27': 31, '2021-01-28': 32, '2021-01-29': 33, '2021-02-01': 34, '2021-02-02': 35, '2021-02-03': 36, '2021-02-04': 37, '2021-02-05': 38, '2021-02-08': 39, '2021-02-09': 40, '2021-02-10': 41, '2021-02-11': 42, '2021-02-12': 43, '2021-02-16': 44, '2021-02-17': 45, '2021-02-18': 46, '2021-02-19': 47, '2021-02-22': 48, '2021-02-23': 49, '2021-02-24': 50, '2021-02-25': 51, '2021-02-26': 52, '2021-03-01': 53, '2021-03-02': 54, '2021-03-03': 55, '2021-03-04': 56, '2021-03-05': 57, '2021-03-08': 58, '2021-03-09': 59, '2021-03-10': 60, '2021-03-11': 61, '2021-03-12': 62, '2021-03-15': 63, '2021-03-16': 64, '2021-03-17': 65, '2021-03-18': 66, '2021-03-19': 67, '2021-03-22': 68, '2021-03-23': 69, '2021-03-24': 70, '2021-03-25': 71, '2021-03-26': 72, '2021-03-29': 73, '2021-03-30': 74, '2021-03-31': 75, '2021-04-01': 76, '2021-04-05': 77, '2021-04-06': 78, '2021-04-07': 79, '2021-04-08': 80, '2021-04-09': 81, '2021-04-12': 82, '2021-04-13': 83, '2021-04-14': 84, '2021-04-15': 85, '2021-04-16': 86, '2021-04-19': 87, '2021-04-20': 88, '2021-04-21': 89, '2021-04-22': 90, '2021-04-23': 91, '2021-04-26': 92, '2021-04-27': 93, '2021-04-28': 94, '2021-04-29': 95, '2021-04-30': 96, '2021-05-03': 97, '2021-05-04': 98, '2021-05-05': 99, '2021-05-06': 100, '2021-05-07': 101, '2021-05-10': 102, '2021-05-11': 103, '2021-05-12': 104, '2021-05-13': 105, '2021-05-14': 106, '2021-05-17': 107, '2021-05-18': 108, '2021-05-19': 109, '2021-05-20': 110, '2021-05-21': 111, '2021-05-24': 112, '2021-05-25': 113, '2021-05-26': 114, '2021-05-27': 115, '2021-05-28': 116, '2021-06-01': 117, '2021-06-02': 118, '2021-06-03': 119, '2021-06-04': 120, '2021-06-07': 121, '2021-06-08': 122, '2021-06-09': 123, '2021-06-10': 124, '2021-06-11': 125, '2021-06-14': 126, '2021-06-15': 127, '2021-06-16': 128, '2021-06-17': 129, '2021-06-18': 130, '2021-06-21': 131, '2021-06-22': 132, '2021-06-23': 133, '2021-06-24': 134, '2021-06-25': 135, '2021-06-28': 136, '2021-06-29': 137, '2021-06-30': 138, '2021-07-01': 139, '2021-07-02': 140, '2021-07-06': 141, '2021-07-07': 142, '2021-07-08': 143, '2021-07-09': 144, '2021-07-12': 145, '2021-07-13': 146, '2021-07-14': 147, '2021-07-15': 148, '2021-07-16': 149, '2021-07-19': 150, '2021-07-20': 151, '2021-07-21': 152, '2021-07-22': 153, '2021-07-23': 154, '2021-07-26': 155, '2021-07-27': 156, '2021-07-28': 157, '2021-07-29': 158, '2021-07-30': 159, '2021-08-02': 160, '2021-08-03': 161, '2021-08-04': 162, '2021-08-05': 163, '2021-08-06': 164, '2021-08-09': 165, '2021-08-10': 166, '2021-08-11': 167, '2021-08-12': 168, '2021-08-13': 169, '2021-08-16': 170, '2021-08-17': 171, '2021-08-18': 172, '2021-08-19': 173, '2021-08-20': 174, '2021-08-23': 175, '2021-08-24': 176, '2021-08-25': 177, '2021-08-26': 178, '2021-08-27': 179, '2021-08-30': 180, '2021-08-31': 181, '2021-09-01': 182, '2021-09-02': 183, '2021-09-03': 184, '2021-09-07': 185, '2021-09-08': 186, '2021-09-09': 187, '2021-09-10': 188, '2021-09-13': 189, '2021-09-14': 190, '2021-09-15': 191, '2021-09-16': 192, '2021-09-17': 193, '2021-09-20': 194, '2021-09-21': 195, '2021-09-22': 196, '2021-09-23': 197, '2021-09-24': 198, '2021-09-27': 199, '2021-09-28': 200, '2021-09-29': 201, '2021-09-30': 202, '2021-10-01': 203, '2021-10-04': 204, '2021-10-05': 205, '2021-10-06': 206, '2021-10-07': 207, '2021-10-08': 208, '2021-10-11': 209, '2021-10-12': 210, '2021-10-13': 211, '2021-10-14': 212, '2021-10-15': 213, '2021-10-18': 214, '2021-10-19': 215, '2021 ...

# %%
data['Date']=data['Date'].map(Date_mapping)

# %%
data
# Out:
#      Date        Open        High         Low       Close   Adj Close  \
# 0       0  146.000000  165.000000  141.250000  144.710007  144.710007
# 1       1  146.550003  151.500000  135.100006  139.250000  139.250000
# 2       2  135.000000  135.300003  125.160004  130.000000  130.000000
# 3       3  126.690002  127.599998  121.500000  124.800003  124.800003
# 4       4  125.830002  142.000000  124.910004  137.990005  137.990005
# ..    ...         ...         ...         ...         ...         ...
# 804   804  153.270004  155.300003  150.824997  152.660004  152.660004
# 805   805  149.960007  150.179993  148.559998  149.270004  149.270004
# 806   806  150.000000  152.470001  149.229996  152.059998  152.059998
# 807   807  152.029999  154.899994  151.789993  153.429993  153.429993
# 808   808  153.399994  160.000000  153.220001  157.470001  157.470001
#
#        Volume
# 0    70447500
# 1    26980800
# 2    16966100
# 3    10914400
# 4    20409600
# ..        ...
# 804   4851100
# 805   5277900
# 806   4623700
# 807   4329100
# 808   8002300
#
# [809 rows x 7 columns]

# %%
data['OPEN']=data['Open']

# %%
data=data.drop("Open",axis=1)

# %%
data
# Out:
#      Date        High         Low       Close   Adj Close    Volume  \
# 0       0  165.000000  141.250000  144.710007  144.710007  70447500
# 1       1  151.500000  135.100006  139.250000  139.250000  26980800
# 2       2  135.300003  125.160004  130.000000  130.000000  16966100
# 3       3  127.599998  121.500000  124.800003  124.800003  10914400
# 4       4  142.000000  124.910004  137.990005  137.990005  20409600
# ..    ...         ...         ...         ...         ...       ...
# 804   804  155.300003  150.824997  152.660004  152.660004   4851100
# 805   805  150.179993  148.559998  149.270004  149.270004   5277900
# 806   806  152.470001  149.229996  152.059998  152.059998   4623700
# 807   807  154.899994  151.789993  153.429993  153.429993   4329100
# 808   808  160.000000  153.220001  157.470001  157.470001   8002300
#
#            OPEN
# 0    146.000000
# 1    146.550003
# 2    135.000000
# 3    126.690002
# 4    125.830002
# ..          ...
# 804  153.270004
# 805  149.960007
# 806  150.000000
# 807  152.029999
# 808  153.399994
#
# [809 rows x 7 columns]

# %% [markdown]
# ## Creating the features and labels over here

# %%
X=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %% [markdown]
# ## Splitting the dataset into training set and testing set over here to avoid the problem of overfitting

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor

# Assuming X_train, X_test, y_train, y_test are already defined

# Initialize regressors
regressors = {
    "Random Forest": RandomForestRegressor(),
    "Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(),
    "Lasso Regression": Lasso(),
    "Support Vector Machine": SVR(),
    "K-Nearest Neighbors": KNeighborsRegressor(),
    "Decision Tree": DecisionTreeRegressor(),
    "XGBoost": XGBRegressor(),
    "CatBoost": CatBoostRegressor(silent=True)  # silent=True to suppress CatBoost output
}

# Train and evaluate each regressor
results = {}
for name, regressor in regressors.items():
    regressor.fit(X_train, y_train)
    y_pred = regressor.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    results[name] = mse

# Select the regressor with the lowest mean squared error (MSE)
best_regressor = min(results, key=results.get)
lowest_mse = results[best_regressor]

print("Best Regressor:", best_regressor)
print("Mean Squared Error:", lowest_mse)
# Out:
# Best Regressor: Ridge Regression
# Mean Squared Error: 4.7427013466601515

# %%
regressor=Ridge()
regressor.fit(X_train,y_train)
# Out:
# Ridge()

# %%
y_pred=regressor.predict((X_test))
np.set_printoptions(precision=2)
print(np.concatenate((y_test.reshape(len(y_test),1),y_pred.reshape(len(y_pred),1)),1))
# Out:
# [[108.34 109.42]
#  [168.1  167.64]
#  [186.97 185.35]
#  [ 94.08  94.05]
#  [164.99 162.65]
#  [146.9  146.18]
#  [109.19 108.05]
#  [ 93.53  93.71]
#  [168.98 166.25]
#  [132.86 135.39]
#  [105.6  105.05]
#  [107.74 108.15]
#  [170.   171.03]
#  [170.2  169.52]
#  [123.   121.49]
#  [118.25 119.58]
#  [110.96 110.95]
#  [156.5  154.08]
#  [137.4  136.62]
#  [165.3  166.9 ]
#  [126.15 125.63]
#  [ 92.97  93.22]
#  [191.66 190.47]
#  [106.7  107.42]
#  [114.09 112.08]
#  [141.   139.68]
#  [129.28 131.41]
#  [134.   135.26]
#  [150.08 151.64]
#  [122.39 122.36]
#  [172.69 173.93]
#  [148.15 147.98]
#  [171.99 170.53]
#  [119.76 121.02]
#  [121.5  121.44]
#  [152.55 149.12]
#  [144.9  145.47]
#  [141.93 142.63]
#  [ 92.49  90.47]
#  [119.71 118.38]
#  [153.82 154.97]
#  [140.14 139.61]
#  [189.38 188.21]
#  [ 99.92 100.92]
#  [129.45 130.71]
#  [138.19 138.96]
#  [113.95 114.85]
#  [138.96 138.12]
#  [187.64 200.76]
#  [190.23 191.81]
#  [111.19 111.61]
#  [182.09 182.81]
#  [152.19 149.88]
#  [103.11 104.92]
#  [177.19 176.77]
#  [199.2  204.55]
#  [ 97.52  97.04]
#  [113.56 113.45]
#  [118.34 118.  ]
#  [ 97.5   98.4 ]
#  [150.   149.88]
#  [172.52 171.33]
#  [138.54 136.52]
#  [119.7  121.45]
#  [107.47 108.13]
#  [148.91 150.4 ]
#  [126.65 126.45]
#  [149.21 150.09]
#  [201.44 194.21]
#  [134.43 134.41]
#  [207.   209.34]
#  [ 95.53  97.84]
#  [153.4  155.69]
#  [125.74 128.99]
#  [153.27 153.09]
#  [141.26 139.88]
#  [117.15 116.99]
#  [107.7  107.35]
#  [102.64 101.62]
#  [185.43 189.3 ]
#  [177.   176.91]
#  [119.67 120.82]
#  [139.1  138.75]
#  [100.02 101.45]
#  [146.55 144.89]
#  [120.25 121.42]
#  [143.   147.57]
#  [148.99 149.42]
#  [135.55 134.74]
#  [167.76 168.96]
#  [125.09 127.05]
#  [168.78 169.82]
#  [120.85 120.18]
#  [169.3  165.92]
#  [106.98 105.77]
#  [160.84 163.75]
#  [115.52 116.79]
#  [114.8  114.44]
#  [138.52 138.03]
#  [ 99.7  100.13]
#  [153.86 153.74]
#  [125.29 127.98]
#  [ 96.78  99.96]
#  [118.94 117.78]
#  [106.04 106.29]
#  [153.79 152.43]
#  [127.   128.62]
#  [124.25 125.93]
#  [109.14 109.95]
#  [ 97.01  96.3 ]
#  [139.87 139.83]
#  [125.5  127.57]
#  [116.37 117.14]
#  [125.06 124.12]
#  [125.99 125.75]
#  [115.37 114.7 ]
#  [199.93 194.64]
#  [ 96.83  95.2 ]
#  [185.61 185.53]
#  [146.37 149.37]
#  [122.51 122.48]
#  [110.52 109.39]
#  [ 96.23  95.02]
#  [131.36 132.21]
#  [172.13 171.11]
#  [113.89 113.9 ]
#  [190.98 197.86]
#  [205.59 206.29]
#  [139.35 140.28]
#  [113.18 113.54]
#  [150.6  149.08]
#  [150.53 152.76]
#  [112.   113.09]
#  [159.16 161.06]
#  [118.18 118.05]
#  [196.85 201.52]
#  [160.29 160.31]
#  [151.16 153.39]
#  [127.25 129.68]
#  [111.36 109.08]
#  [114.97 114.73]
#  [119.96 120.79]
#  [145.1  145.63]
#  [135.   130.07]
#  [150.31 148.16]
#  [170.5  168.32]
#  [129.05 128.97]
#  [143.59 144.54]
#  [145.   147.09]
#  [127.   126.64]
#  [111.67 112.87]
#  [175.63 178.29]
#  [108.22 108.6 ]
#  [119.43 119.19]
#  [ 88.52  86.81]
#  [159.18 160.67]
#  [114.5  113.96]
#  [105.46 105.02]
#  [173.1  174.46]
#  [189.   181.04]
#  [118.15 118.77]
#  [181.14 180.15]]

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9943294882041134
