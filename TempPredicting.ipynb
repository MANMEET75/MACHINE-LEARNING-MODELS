# %% [markdown]
# ## Importing the essential libraries over here

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Importing the dataset over here

# %%
data=pd.read_csv("hour.csv")

# %%
data.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ## Taking care of duplicates if present over here

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Taking care of missing values if present over here

# %%
data.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ## Filtering all the numerical features over here

# %%
numerical_features=[feature for feature in data.columns if data[feature].dtype!='O']
for feature in numerical_features:
  print(feature)
# Out:
# instant
# season
# yr
# mnth
# hr
# holiday
# weekday
# workingday
# weathersit
# temp
# atemp
# hum
# windspeed
# casual
# registered
# cnt

# %%
data[numerical_features]
# Out:
#        instant  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0            1       1   0     1   0        0        6           0
# 1            2       1   0     1   1        0        6           0
# 2            3       1   0     1   2        0        6           0
# 3            4       1   0     1   3        0        6           0
# 4            5       1   0     1   4        0        6           0
# ...        ...     ...  ..   ...  ..      ...      ...         ...
# 17374    17375       1   1    12  19        0        1           1
# 17375    17376       1   1    12  20        0        1           1
# 17376    17377       1   1    12  21        0        1           1
# 17377    17378       1   1    12  22        0        1           1
# 17378    17379       1   1    12  23        0        1           1
#
#        weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0               1  0.24  0.2879  0.81     0.0000       3          13   16
# 1               1  0.22  0.2727  0.80     0.0000       8          32   40
# 2               1  0.22  0.2727  0.80     0.0000       5          27   32
# 3               1  0.24  0.2879  0.75     0.0000       3          10   13
# 4               1  0.24  0.2879  0.75     0.0000       0           1    1
# ...           ...   ...     ...   ...        ...     ...         ...  ...
# 17374           2  0.26  0.2576  0.60     0.1642      11         108  119
# 17375           2  0.26  0.2576  0.60     0.1642       8          81   89
# 17376           1  0.26  0.2576  0.60     0.1642       7          83   90
# 17377           1  0.26  0.2727  0.56     0.1343      13          48   61
# 17378           1  0.26  0.2727  0.65     0.1343      12          37   49
#
# [17379 rows x 16 columns]

# %% [markdown]
# ## Filtering all the categorical features over here

# %%
cat_features=[feature for feature in data.columns if data[feature].dtype=='O']
for feature in cat_features:
  print(feature)
# Out:
# dteday

# %%
data[cat_features]
# Out:
#            dteday
# 0      2011-01-01
# 1      2011-01-01
# 2      2011-01-01
# 3      2011-01-01
# 4      2011-01-01
# ...           ...
# 17374  2012-12-31
# 17375  2012-12-31
# 17376  2012-12-31
# 17377  2012-12-31
# 17378  2012-12-31
#
# [17379 rows x 1 columns]

# %% [markdown]
# ## Encoding the categorical features into numerical features over here

# %%
for feature in cat_features:
  feature_mapping={category:index for index,category in enumerate(data[feature].unique())}
  data[feature]=data[feature].map(feature_mapping)

# %%
data
# Out:
#        instant  dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0            1       0       1   0     1   0        0        6           0
# 1            2       0       1   0     1   1        0        6           0
# 2            3       0       1   0     1   2        0        6           0
# 3            4       0       1   0     1   3        0        6           0
# 4            5       0       1   0     1   4        0        6           0
# ...        ...     ...     ...  ..   ...  ..      ...      ...         ...
# 17374    17375     730       1   1    12  19        0        1           1
# 17375    17376     730       1   1    12  20        0        1           1
# 17376    17377     730       1   1    12  21        0        1           1
# 17377    17378     730       1   1    12  22        0        1           1
# 17378    17379     730       1   1    12  23        0        1           1
#
#        weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0               1  0.24  0.2879  0.81     0.0000       3          13   16
# 1               1  0.22  0.2727  0.80     0.0000       8          32   40
# 2               1  0.22  0.2727  0.80     0.0000       5          27   32
# 3               1  0.24  0.2879  0.75     0.0000       3          10   13
# 4               1  0.24  0.2879  0.75     0.0000       0           1    1
# ...           ...   ...     ...   ...        ...     ...         ...  ...
# 17374           2  0.26  0.2576  0.60     0.1642      11         108  119
# 17375           2  0.26  0.2576  0.60     0.1642       8          81   89
# 17376           1  0.26  0.2576  0.60     0.1642       7          83   90
# 17377           1  0.26  0.2727  0.56     0.1343      13          48   61
# 17378           1  0.26  0.2727  0.65     0.1343      12          37   49
#
# [17379 rows x 17 columns]

# %%
data['Temp']=data['temp']
data.drop(['temp'],axis=1,inplace=True)

# %% [markdown]
# ## Creating the feature and labels over here

# %%
X=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %% [markdown]
# ## Splitting the dataset into training set and testing set to avoid the problem of overfitting over here

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# ## Training the model on the training dataset over here

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(n_estimators=10,random_state=0)
regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %% [markdown]
# ## Evaluating the performance of the model on the training dataset over here

# %%
y_pred=regressor.predict(X_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1),y_test.reshape(len(y_test),1)),1))
# Out:
# [[0.56 0.56]
#  [0.44 0.44]
#  [0.44 0.44]
#  ...
#  [0.6  0.62]
#  [0.29 0.26]
#  [0.3  0.3 ]]

# %% [markdown]
# ## Evaluating the performance using metrics over here

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9985246768957049

# %% [markdown]
# ## Finding the difference between the actual vs predicted value over here

# %%
result=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})

# %%
result['Difference']=np.abs(result['Predicted']-result['Actual'])

# %%
result
# Out:
#       Actual  Predicted    Difference
# 0       0.56      0.560  1.443290e-15
# 1       0.44      0.440  5.551115e-17
# 2       0.44      0.440  5.551115e-17
# 3       0.26      0.260  5.551115e-17
# 4       0.66      0.646  1.400000e-02
# ...      ...        ...           ...
# 3471    0.60      0.596  4.000000e-03
# 3472    0.76      0.760  0.000000e+00
# 3473    0.62      0.604  1.600000e-02
# 3474    0.26      0.294  3.400000e-02
# 3475    0.30      0.300  1.110223e-16
#
# [3476 rows x 3 columns]
